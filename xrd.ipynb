# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.symmetry.analyzer import *
from pymatgen.io.cif import *
from pymatgen.core.operations import *
from tabulate import tabulate
from pymatgen.symmetry.site_symmetries import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pymatgen.analysis.diffraction.xrd import *

# %%
USER_API_KEY = "VE2Z5ZyFtdd4NPJ6F"
with MPRester(USER_API_KEY) as m:
    structure = m.get_structure_by_material_id("mp-568662")

# %% [markdown]
# Déterminer les 3 premiers pics du diffractogramme correspondant (en indiquant les indices hkl associés) pour un rayonnement X incident Cu Kα de longueur d’onde λ=1.54060 Å.

# %%
xrd = XRDCalculator(symprec=0.1)
xrdpattern = xrd.get_pattern(structure)
hkls = xrdpattern.hkls

# %% [markdown]
# Le chlorure de baryum cristallise à la température ambiante dans une structure orthorhombique de groupe d'espace Pnma (a = 7,865 Å, b = 4,731 Å et c = 9,421 Å).
#
# Cette notation n'a aucune implications techniques, mais permet d'appliquer des permutations circulaires d'indices pour définir des familles de plans
#
# On ne considérera pas non plus la troisième raie du spectre. En effet, son intensité est beaucoup plus faible que celle des raies adjacentes, et est donc probablement due à une interférence "parasite". On considèrera donc les première, seconde et quatrième raies.

# %%
xrd.show_plot(structure)

# %% [markdown]
# On peut donc déterminer que les 3 premiers pics du pictogramme sont compris entre un angle de 0° et 41°.

# %%
xrd.show_plot(structure,two_theta_range=[0,41])

# %%
print("Pic n°1 :")
print("Indices de Bravais-Miller (h,k,l): ",str(xrdpattern.hkls[0][0]['hkl']))

print("Pic n°2 :")
print("Indices de Bravais-Miller (h,k,l): ",str(xrdpattern.hkls[1][0]['hkl']))

print("Pic n°3 :")
print("Indices de Bravais-Miller (h,k,l): ",str(xrdpattern.hkls[3][0]['hkl']))
# Out:
# Pic n°1 :
# Indices de Bravais-Miller (h,k,l):  (1, 1, 1)
# Pic n°2 :
# Indices de Bravais-Miller (h,k,l):  (2, 0, 0)
# Pic n°3 :
# Indices de Bravais-Miller (h,k,l):  (3, 1, 1)
